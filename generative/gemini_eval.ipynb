# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import pandas as pd
import os 

def calculate_metrics(df):
    """
    Sometimes Llama3 does not say yes or no, thats why i classified them as -1
    This rarely happens, for example in dirty_Walmart-amazon it happened one single 
    time out of 8000 prompts, thats why i omit them"""
    df = df[df['pred'] != -1]
    return {
        'Accuracy': accuracy_score(df['label'], df['pred']),
        'Precision': precision_score(df['label'], df['pred']),
        'Recall': recall_score(df['label'], df['pred']),
        'F1': f1_score(df['label'], df['pred'])
    }

dir = 'gemini_predictions'

datasets = {}
for file in os.listdir(dir):
    if file.endswith('.csv'):
        df = pd.read_csv(f'{dir}/{file}')
        datasets[file.split(".")[0]] = df

results = {name: calculate_metrics(df) for name, df in datasets.items()}

df_all = pd.DataFrame(results).T
df_all.style.background_gradient(cmap='RdYlGn', axis=1)
# Out:
# <style type="text/css">
# #T_00e81_row0_col0, #T_00e81_row1_col2, #T_00e81_row2_col0, #T_00e81_row3_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_00e81_row0_col1 {
#   background-color: #08773f;
#   color: #f1f1f1;
# }
# #T_00e81_row0_col2, #T_00e81_row1_col1, #T_00e81_row2_col1, #T_00e81_row3_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_00e81_row0_col3 {
#   background-color: #fed481;
#   color: #000000;
# }
# #T_00e81_row1_col0 {
#   background-color: #c5e67e;
#   color: #000000;
# }
# #T_00e81_row1_col3 {
#   background-color: #fdc776;
#   color: #000000;
# }
# #T_00e81_row2_col2 {
#   background-color: #9bd469;
#   color: #000000;
# }
# #T_00e81_row2_col3 {
#   background-color: #fdb96a;
#   color: #000000;
# }
# #T_00e81_row3_col0 {
#   background-color: #f8fcb6;
#   color: #000000;
# }
# #T_00e81_row3_col3 {
#   background-color: #fdb567;
#   color: #000000;
# }
# </style>
# <table id="T_00e81">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_00e81_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_00e81_level0_col1" class="col_heading level0 col1" >Precision</th>
#       <th id="T_00e81_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_00e81_level0_col3" class="col_heading level0 col3" >F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_00e81_level0_row0" class="row_heading level0 row0" >structured_Beer</th>
#       <td id="T_00e81_row0_col0" class="data row0 col0" >0.928375</td>
#       <td id="T_00e81_row0_col1" class="data row0 col1" >0.916667</td>
#       <td id="T_00e81_row0_col2" class="data row0 col2" >0.589286</td>
#       <td id="T_00e81_row0_col3" class="data row0 col3" >0.717391</td>
#     </tr>
#     <tr>
#       <th id="T_00e81_level0_row1" class="row_heading level0 row1" >dirty_iTunes-Amazon</th>
#       <td id="T_00e81_row1_col0" class="data row1 col0" >0.717890</td>
#       <td id="T_00e81_row1_col1" class="data row1 col1" >0.462687</td>
#       <td id="T_00e81_row1_col2" class="data row1 col2" >0.861111</td>
#       <td id="T_00e81_row1_col3" class="data row1 col3" >0.601942</td>
#     </tr>
#     <tr>
#       <th id="T_00e81_level0_row2" class="row_heading level0 row2" >structured_Fodors-Zagats</th>
#       <td id="T_00e81_row2_col0" class="data row2 col0" >0.948413</td>
#       <td id="T_00e81_row2_col1" class="data row2 col1" >0.728972</td>
#       <td id="T_00e81_row2_col2" class="data row2 col2" >0.886364</td>
#       <td id="T_00e81_row2_col3" class="data row2 col3" >0.800000</td>
#     </tr>
#     <tr>
#       <th id="T_00e81_level0_row3" class="row_heading level0 row3" >structured_iTunes-Amazon</th>
#       <td id="T_00e81_row3_col0" class="data row3 col0" >0.642202</td>
#       <td id="T_00e81_row3_col1" class="data row3 col1" >0.398305</td>
#       <td id="T_00e81_row3_col2" class="data row3 col2" >0.870370</td>
#       <td id="T_00e81_row3_col3" class="data row3 col3" >0.546512</td>
#     </tr>
#   </tbody>
# </table>

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

def calculate_metrics(df):
    df = df[df['pred'] != -1]
    metrics = {}
    for name, group in df.groupby(['general_or_domain', 'simple_or_complex']):
        label = group['label']
        pred = group['pred']
        metrics[name] = {
            'Accuracy': accuracy_score(label, pred),
            'Precision': precision_score(label, pred, zero_division=0),
            'Recall': recall_score(label, pred, zero_division=0),
            'F1': f1_score(label, pred, zero_division=0)
        }
    return metrics

results = {}
for name, df in datasets.items():
    results.update({(name,) + key: value for key, value in calculate_metrics(df).items()})

df_all = pd.DataFrame(results).T
df_all.index.names = ['Dataset', 'GeneralOrDomain', 'SimpleOrComplex']
df_all.style.background_gradient(subset=['Accuracy', 'Precision', 'Recall', 'F1'], cmap='RdYlGn')
# Out:
# <style type="text/css">
# #T_e58d1_row0_col0, #T_e58d1_row2_col0 {
#   background-color: #0e8245;
#   color: #f1f1f1;
# }
# #T_e58d1_row0_col1, #T_e58d1_row2_col1, #T_e58d1_row11_col1 {
#   background-color: #2da155;
#   color: #f1f1f1;
# }
# #T_e58d1_row0_col2, #T_e58d1_row2_col2 {
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_e58d1_row0_col3, #T_e58d1_row2_col3 {
#   background-color: #7ac665;
#   color: #000000;
# }
# #T_e58d1_row1_col0 {
#   background-color: #219c52;
#   color: #f1f1f1;
# }
# #T_e58d1_row1_col1, #T_e58d1_row4_col2, #T_e58d1_row9_col1, #T_e58d1_row10_col2, #T_e58d1_row11_col0, #T_e58d1_row11_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_e58d1_row1_col2, #T_e58d1_row14_col0, #T_e58d1_row14_col1, #T_e58d1_row14_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_e58d1_row1_col3 {
#   background-color: #fdc574;
#   color: #000000;
# }
# #T_e58d1_row3_col0 {
#   background-color: #249d53;
#   color: #f1f1f1;
# }
# #T_e58d1_row3_col1 {
#   background-color: #51b35e;
#   color: #f1f1f1;
# }
# #T_e58d1_row3_col2 {
#   background-color: #de402e;
#   color: #f1f1f1;
# }
# #T_e58d1_row3_col3 {
#   background-color: #fee797;
#   color: #000000;
# }
# #T_e58d1_row4_col0, #T_e58d1_row13_col2 {
#   background-color: #fee593;
#   color: #000000;
# }
# #T_e58d1_row4_col1 {
#   background-color: #ea5739;
#   color: #f1f1f1;
# }
# #T_e58d1_row4_col3 {
#   background-color: #fca85e;
#   color: #000000;
# }
# #T_e58d1_row5_col0 {
#   background-color: #16914d;
#   color: #f1f1f1;
# }
# #T_e58d1_row5_col1, #T_e58d1_row6_col2, #T_e58d1_row12_col2, #T_e58d1_row14_col2 {
#   background-color: #108647;
#   color: #f1f1f1;
# }
# #T_e58d1_row5_col2, #T_e58d1_row7_col2 {
#   background-color: #eef8a8;
#   color: #000000;
# }
# #T_e58d1_row5_col3, #T_e58d1_row10_col0 {
#   background-color: #48ae5c;
#   color: #f1f1f1;
# }
# #T_e58d1_row6_col0 {
#   background-color: #d93429;
#   color: #f1f1f1;
# }
# #T_e58d1_row6_col1 {
#   background-color: #b50f26;
#   color: #f1f1f1;
# }
# #T_e58d1_row6_col3 {
#   background-color: #c01a27;
#   color: #f1f1f1;
# }
# #T_e58d1_row7_col0 {
#   background-color: #63bc62;
#   color: #f1f1f1;
# }
# #T_e58d1_row7_col1 {
#   background-color: #d7ee8a;
#   color: #000000;
# }
# #T_e58d1_row7_col3 {
#   background-color: #d1ec86;
#   color: #000000;
# }
# #T_e58d1_row8_col0 {
#   background-color: #04703b;
#   color: #f1f1f1;
# }
# #T_e58d1_row8_col1 {
#   background-color: #91d068;
#   color: #000000;
# }
# #T_e58d1_row8_col2 {
#   background-color: #148e4b;
#   color: #f1f1f1;
# }
# #T_e58d1_row8_col3 {
#   background-color: #128a49;
#   color: #f1f1f1;
# }
# #T_e58d1_row9_col0 {
#   background-color: #06733d;
#   color: #f1f1f1;
# }
# #T_e58d1_row9_col2 {
#   background-color: #feeda1;
#   color: #000000;
# }
# #T_e58d1_row9_col3 {
#   background-color: #6bbf64;
#   color: #000000;
# }
# #T_e58d1_row10_col1 {
#   background-color: #fdaf62;
#   color: #000000;
# }
# #T_e58d1_row10_col3 {
#   background-color: #fffbb8;
#   color: #000000;
# }
# #T_e58d1_row11_col2 {
#   background-color: #45ad5b;
#   color: #f1f1f1;
# }
# #T_e58d1_row12_col0 {
#   background-color: #fee08b;
#   color: #000000;
# }
# #T_e58d1_row12_col1 {
#   background-color: #e65036;
#   color: #f1f1f1;
# }
# #T_e58d1_row12_col3 {
#   background-color: #f99355;
#   color: #000000;
# }
# #T_e58d1_row13_col0 {
#   background-color: #4bb05c;
#   color: #f1f1f1;
# }
# #T_e58d1_row13_col1 {
#   background-color: #87cb67;
#   color: #000000;
# }
# #T_e58d1_row13_col3 {
#   background-color: #c9e881;
#   color: #000000;
# }
# #T_e58d1_row15_col0 {
#   background-color: #fffdbc;
#   color: #000000;
# }
# #T_e58d1_row15_col1 {
#   background-color: #f47044;
#   color: #f1f1f1;
# }
# #T_e58d1_row15_col2 {
#   background-color: #60ba62;
#   color: #f1f1f1;
# }
# #T_e58d1_row15_col3 {
#   background-color: #fdad60;
#   color: #000000;
# }
# </style>
# <table id="T_e58d1">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e58d1_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_e58d1_level0_col1" class="col_heading level0 col1" >Precision</th>
#       <th id="T_e58d1_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_e58d1_level0_col3" class="col_heading level0 col3" >F1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Dataset</th>
#       <th class="index_name level1" >GeneralOrDomain</th>
#       <th class="index_name level2" >SimpleOrComplex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e58d1_level0_row0" class="row_heading level0 row0" rowspan="4">structured_Beer</th>
#       <th id="T_e58d1_level1_row0" class="row_heading level1 row0" rowspan="2">domain</th>
#       <th id="T_e58d1_level2_row0" class="row_heading level2 row0" >complex</th>
#       <td id="T_e58d1_row0_col0" class="data row0 col0" >0.945055</td>
#       <td id="T_e58d1_row0_col1" class="data row0 col1" >0.909091</td>
#       <td id="T_e58d1_row0_col2" class="data row0 col2" >0.714286</td>
#       <td id="T_e58d1_row0_col3" class="data row0 col3" >0.800000</td>
#     </tr>
#     <tr>
#       <th id="T_e58d1_level2_row1" class="row_heading level2 row1" >simple</th>
#       <td id="T_e58d1_row1_col0" class="data row1 col0" >0.912088</td>
#       <td id="T_e58d1_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_e58d1_row1_col2" class="data row1 col2" >0.428571</td>
#       <td id="T_e58d1_row1_col3" class="data row1 col3" >0.600000</td>
#     </tr>
#     <tr>
#       <th id="T_e58d1_level1_row2" class="row_heading level1 row2" rowspan="2">general</th>
#       <th id="T_e58d1_level2_row2" class="row_heading level2 row2" >complex</th>
#       <td id="T_e58d1_row2_col0" class="data row2 col0" >0.945055</td>
#       <td id="T_e58d1_row2_col1" class="data row2 col1" >0.909091</td>
#       <td id="T_e58d1_row2_col2" class="data row2 col2" >0.714286</td>
#       <td id="T_e58d1_row2_col3" class="data row2 col3" >0.800000</td>
#     </tr>
#     <tr>
#       <th id="T_e58d1_level2_row3" class="row_heading level2 row3" >simple</th>
#       <td id="T_e58d1_row3_col0" class="data row3 col0" >0.911111</td>
#       <td id="T_e58d1_row3_col1" class="data row3 col1" >0.875000</td>
#       <td id="T_e58d1_row3_col2" class="data row3 col2" >0.500000</td>
#       <td id="T_e58d1_row3_col3" class="data row3 col3" >0.636364</td>
#     </tr>
#     <tr>
#       <th id="T_e58d1_level0_row4" class="row_heading level0 row4" rowspan="4">dirty_iTunes-Amazon</th>
#       <th id="T_e58d1_level1_row4" class="row_heading level1 row4" rowspan="2">domain</th>
#       <th id="T_e58d1_level2_row4" class="row_heading level2 row4" >complex</th>
#       <td id="T_e58d1_row4_col0" class="data row4 col0" >0.633028</td>
#       <td id="T_e58d1_row4_col1" class="data row4 col1" >0.402985</td>
#       <td id="T_e58d1_row4_col2" class="data row4 col2" >1.000000</td>
#       <td id="T_e58d1_row4_col3" class="data row4 col3" >0.574468</td>
#     </tr>
#     <tr>
#       <th id="T_e58d1_level2_row5" class="row_heading level2 row5" >simple</th>
#       <td id="T_e58d1_row5_col0" class="data row5 col0" >0.926606</td>
#       <td id="T_e58d1_row5_col1" class="data row5 col1" >0.952381</td>
#       <td id="T_e58d1_row5_col2" class="data row5 col2" >0.740741</td>
#       <td id="T_e58d1_row5_col3" class="data row5 col3" >0.833333</td>
#     </tr>
#     <tr>
#       <th id="T_e58d1_level1_row6" class="row_heading level1 row6" rowspan="2">general</th>
#       <th id="T_e58d1_level2_row6" class="row_heading level2 row6" >complex</th>
#       <td id="T_e58d1_row6_col0" class="data row6 col0" >0.449541</td>
#       <td id="T_e58d1_row6_col1" class="data row6 col1" >0.305882</td>
#       <td id="T_e58d1_row6_col2" class="data row6 col2" >0.962963</td>
#       <td id="T_e58d1_row6_col3" class="data row6 col3" >0.464286</td>
#     </tr>
#     <tr>
#       <th id="T_e58d1_level2_row7" class="row_heading level2 row7" >simple</th>
#       <td id="T_e58d1_row7_col0" class="data row7 col0" >0.862385</td>
#       <td id="T_e58d1_row7_col1" class="data row7 col1" >0.714286</td>
#       <td id="T_e58d1_row7_col2" class="data row7 col2" >0.74074

# %%
def calculate_metrics(df):
    df = df[df['pred'] != -1]
    metrics = {}
    for category in ['general_or_domain', 'simple_or_complex']:
        for name, group in df.groupby(category):
            metrics[name] = {
                'F1': f1_score(group['label'], group['pred'])
            }
    return metrics

results = []
for name, df in datasets.items():
    metrics = calculate_metrics(df)
    results.append((name, 
                    metrics.get('domain', {}).get('F1', None), 
                    metrics.get('general', {}).get('F1', None),
                    metrics.get('simple', {}).get('F1', None),
                    metrics.get('complex', {}).get('F1', None)))

df_all = pd.DataFrame(results, columns=['Dataset', 'Domain F1', 'General F1', 'Simple F1', 'Complex F1'])
df_all.set_index('Dataset', inplace=True)
df_all.style.background_gradient(subset=['Domain F1', 'General F1', 'Simple F1', 'Complex F1'], cmap='RdYlGn', axis=1)
# Out:
# <style type="text/css">
# #T_f4ff8_row0_col0 {
#   background-color: #fbfdba;
#   color: #000000;
# }
# #T_f4ff8_row0_col1 {
#   background-color: #e2f397;
#   color: #000000;
# }
# #T_f4ff8_row0_col2, #T_f4ff8_row1_col3, #T_f4ff8_row2_col3, #T_f4ff8_row3_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_f4ff8_row0_col3, #T_f4ff8_row1_col2, #T_f4ff8_row2_col2, #T_f4ff8_row3_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_f4ff8_row1_col0 {
#   background-color: #e8f59f;
#   color: #000000;
# }
# #T_f4ff8_row1_col1 {
#   background-color: #e24731;
#   color: #f1f1f1;
# }
# #T_f4ff8_row2_col0 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
# }
# #T_f4ff8_row2_col1 {
#   background-color: #ce2827;
#   color: #f1f1f1;
# }
# #T_f4ff8_row3_col0 {
#   background-color: #249d53;
#   color: #f1f1f1;
# }
# #T_f4ff8_row3_col1 {
#   background-color: #b30d26;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f4ff8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f4ff8_level0_col0" class="col_heading level0 col0" >Domain F1</th>
#       <th id="T_f4ff8_level0_col1" class="col_heading level0 col1" >General F1</th>
#       <th id="T_f4ff8_level0_col2" class="col_heading level0 col2" >Simple F1</th>
#       <th id="T_f4ff8_level0_col3" class="col_heading level0 col3" >Complex F1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Dataset</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f4ff8_level0_row0" class="row_heading level0 row0" >structured_Beer</th>
#       <td id="T_f4ff8_row0_col0" class="data row0 col0" >0.711111</td>
#       <td id="T_f4ff8_row0_col1" class="data row0 col1" >0.723404</td>
#       <td id="T_f4ff8_row0_col2" class="data row0 col2" >0.619048</td>
#       <td id="T_f4ff8_row0_col3" class="data row0 col3" >0.800000</td>
#     </tr>
#     <tr>
#       <th id="T_f4ff8_level0_row1" class="row_heading level0 row1" >dirty_iTunes-Amazon</th>
#       <td id="T_f4ff8_row1_col0" class="data row1 col0" >0.661972</td>
#       <td id="T_f4ff8_row1_col1" class="data row1 col1" >0.550898</td>
#       <td id="T_f4ff8_row1_col2" class="data row1 col2" >0.776699</td>
#       <td id="T_f4ff8_row1_col3" class="data row1 col3" >0.514563</td>
#     </tr>
#     <tr>
#       <th id="T_f4ff8_level0_row2" class="row_heading level0 row2" >structured_Fodors-Zagats</th>
#       <td id="T_f4ff8_row2_col0" class="data row2 col0" >0.847059</td>
#       <td id="T_f4ff8_row2_col1" class="data row2 col1" >0.763636</td>
#       <td id="T_f4ff8_row2_col2" class="data row2 col2" >0.864198</td>
#       <td id="T_f4ff8_row2_col3" class="data row2 col3" >0.754386</td>
#     </tr>
#     <tr>
#       <th id="T_f4ff8_level0_row3" class="row_heading level0 row3" >structured_iTunes-Amazon</th>
#       <td id="T_f4ff8_row3_col0" class="data row3 col0" >0.619718</td>
#       <td id="T_f4ff8_row3_col1" class="data row3 col1" >0.495050</td>
#       <td id="T_f4ff8_row3_col2" class="data row3 col2" >0.636364</td>
#       <td id="T_f4ff8_row3_col3" class="data row3 col3" >0.490566</td>
#     </tr>
#   </tbody>
# </table>

# %%
def calculate_metrics(df):
    df = df[df['pred'] != -1]
    metrics = {}
    for (general_or_domain, simple_or_complex), group in df.groupby(['general_or_domain', 'simple_or_complex']):
        name = f'{general_or_domain}_{simple_or_complex}'
        metrics[name] = {
            'F1': f1_score(group['label'], group['pred'])
        }
    return metrics

results = []
for name, df in datasets.items():
    metrics = calculate_metrics(df)
    results.append((name, 
                    metrics.get('domain_simple', {}).get('F1', None), 
                    metrics.get('domain_complex', {}).get('F1', None),
                    metrics.get('general_simple', {}).get('F1', None),
                    metrics.get('general_complex', {}).get('F1', None)))

df_all = pd.DataFrame(results, columns=['Dataset', 'Domain Simple F1', 'Domain Complex F1', 'General Simple F1', 'General Complex F1'])
df_all['Mean F1'] = df_all[['Domain Simple F1', 'Domain Complex F1', 'General Simple F1', 'General Complex F1']].mean(axis=1)
df_all.set_index('Dataset', inplace=True)
df_all.style.background_gradient(subset=['Domain Simple F1', 'Domain Complex F1', 'General Simple F1', 'General Complex F1', 'Mean F1'], cmap='RdYlGn', axis=1)
# Out:
# <style type="text/css">
# #T_edc76_row0_col0, #T_edc76_row1_col3, #T_edc76_row2_col3, #T_edc76_row3_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_edc76_row0_col1, #T_edc76_row0_col3, #T_edc76_row1_col0, #T_edc76_row2_col2, #T_edc76_row3_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_edc76_row0_col2 {
#   background-color: #ee613e;
#   color: #f1f1f1;
# }
# #T_edc76_row0_col4 {
#   background-color: #eef8a8;
#   color: #000000;
# }
# #T_edc76_row1_col1 {
#   background-color: #fdad60;
#   color: #000000;
# }
# #T_edc76_row1_col2 {
#   background-color: #9dd569;
#   color: #000000;
# }
# #T_edc76_row1_col4 {
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_edc76_row2_col0 {
#   background-color: #daf08d;
#   color: #000000;
# }
# #T_edc76_row2_col1 {
#   background-color: #36a657;
#   color: #f1f1f1;
# }
# #T_edc76_row2_col4 {
#   background-color: #d1ec86;
#   color: #000000;
# }
# #T_edc76_row3_col1 {
#   background-color: #fee491;
#   color: #000000;
# }
# #T_edc76_row3_col2 {
#   background-color: #fff7b2;
#   color: #000000;
# }
# #T_edc76_row3_col4 {
#   background-color: #fff6b0;
#   color: #000000;
# }
# </style>
# <table id="T_edc76">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_edc76_level0_col0" class="col_heading level0 col0" >Domain Simple F1</th>
#       <th id="T_edc76_level0_col1" class="col_heading level0 col1" >Domain Complex F1</th>
#       <th id="T_edc76_level0_col2" class="col_heading level0 col2" >General Simple F1</th>
#       <th id="T_edc76_level0_col3" class="col_heading level0 col3" >General Complex F1</th>
#       <th id="T_edc76_level0_col4" class="col_heading level0 col4" >Mean F1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Dataset</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_edc76_level0_row0" class="row_heading level0 row0" >structured_Beer</th>
#       <td id="T_edc76_row0_col0" class="data row0 col0" >0.600000</td>
#       <td id="T_edc76_row0_col1" class="data row0 col1" >0.800000</td>
#       <td id="T_edc76_row0_col2" class="data row0 col2" >0.636364</td>
#       <td id="T_edc76_row0_col3" class="data row0 col3" >0.800000</td>
#       <td id="T_edc76_row0_col4" class="data row0 col4" >0.709091</td>
#     </tr>
#     <tr>
#       <th id="T_edc76_level0_row1" class="row_heading level0 row1" >dirty_iTunes-Amazon</th>
#       <td id="T_edc76_row1_col0" class="data row1 col0" >0.833333</td>
#       <td id="T_edc76_row1_col1" class="data row1 col1" >0.574468</td>
#       <td id="T_edc76_row1_col2" class="data row1 col2" >0.727273</td>
#       <td id="T_edc76_row1_col3" class="data row1 col3" >0.464286</td>
#       <td id="T_edc76_row1_col4" class="data row1 col4" >0.649840</td>
#     </tr>
#     <tr>
#       <th id="T_edc76_level0_row2" class="row_heading level0 row2" >structured_Fodors-Zagats</th>
#       <td id="T_edc76_row2_col0" class="data row2 col0" >0.810811</td>
#       <td id="T_edc76_row2_col1" class="data row2 col1" >0.875000</td>
#       <td id="T_edc76_row2_col2" class="data row2 col2" >0.909091</td>
#       <td id="T_edc76_row2_col3" class="data row2 col3" >0.666667</td>
#       <td id="T_edc76_row2_col4" class="data row2 col4" >0.815392</td>
#     </tr>
#     <tr>
#       <th id="T_edc76_level0_row3" class="row_heading level0 row3" >structured_iTunes-Amazon</th>
#       <td id="T_edc76_row3_col0" class="data row3 col0" >0.734694</td>
#       <td id="T_edc76_row3_col1" class="data row3 col1" >0.559140</td>
#       <td id="T_edc76_row3_col2" class="data row3 col2" >0.578313</td>
#       <td id="T_edc76_row3_col3" class="data row3 col3" >0.436975</td>
#       <td id="T_edc76_row3_col4" class="data row3 col4" >0.577280</td>
#     </tr>
#   </tbody>
# </table>
