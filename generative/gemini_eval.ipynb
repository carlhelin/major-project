# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import pandas as pd
import os 

def calculate_metrics(df):
    """
    Calculate accuracy, precision, recall, and F1 score for the given DataFrame.
    Rows where 'pred' is -1 are omitted because they are not predictions. 
    """
    df = df[df['pred'] != -1]
    return {
        'Accuracy': accuracy_score(df['label'], df['pred']),
        'Precision': precision_score(df['label'], df['pred']),
        'Recall': recall_score(df['label'], df['pred']),
        'F1': f1_score(df['label'], df['pred'])
    }

# List of dataset names
dataset_names = [
    'dirty_DBLP-ACM',
    'dirty_iTunes-Amazon',
    'dirty_Walmart-Amazon',
    'structured_DBLP-ACM',
    'structured_iTunes-Amazon',
    'structured_Walmart-Amazon',
    'structuredBeer',
    'structured_Fodors-Zagats',
    'structured_Amazon-Google',
    'textual_Abt-Buy'
]

# Read datasets into a dictionary
datasets = {}
for name in dataset_names:
    try:
        datasets[name] = pd.read_csv(os.path.join('gemini_predictions', f'{name}.csv'))
    except FileNotFoundError:
        print(f"File {name}.csv not found in the directory 'gemini_predictions'.")

# Calculate metrics for each dataset
results = {name: calculate_metrics(df) for name, df in datasets.items()}

# Convert results to a DataFrame and display with a gradient background
df_all = pd.DataFrame(results).T
df_all.style.background_gradient(cmap='RdYlGn', axis=1)
# Out:
# <style type="text/css">
# #T_84246_row0_col0 {
#   background-color: #0d8044;
#   color: #f1f1f1;
# }
# #T_84246_row0_col1, #T_84246_row1_col1, #T_84246_row2_col2, #T_84246_row3_col1, #T_84246_row4_col1, #T_84246_row5_col2, #T_84246_row6_col2, #T_84246_row7_col1, #T_84246_row8_col2, #T_84246_row9_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_84246_row0_col2, #T_84246_row1_col2, #T_84246_row2_col0, #T_84246_row3_col2, #T_84246_row4_col2, #T_84246_row5_col0, #T_84246_row6_col0, #T_84246_row7_col0, #T_84246_row8_col0, #T_84246_row9_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_84246_row0_col3 {
#   background-color: #feec9f;
#   color: #000000;
# }
# #T_84246_row1_col0 {
#   background-color: #c5e67e;
#   color: #000000;
# }
# #T_84246_row1_col3 {
#   background-color: #fdc776;
#   color: #000000;
# }
# #T_84246_row2_col1, #T_84246_row8_col3 {
#   background-color: #b50f26;
#   color: #f1f1f1;
# }
# #T_84246_row2_col3 {
#   background-color: #ad0826;
#   color: #f1f1f1;
# }
# #T_84246_row3_col0 {
#   background-color: #84ca66;
#   color: #000000;
# }
# #T_84246_row3_col3 {
#   background-color: #fee08b;
#   color: #000000;
# }
# #T_84246_row4_col0 {
#   background-color: #f8fcb6;
#   color: #000000;
# }
# #T_84246_row4_col3 {
#   background-color: #fdb567;
#   color: #000000;
# }
# #T_84246_row5_col1 {
#   background-color: #eef8a8;
#   color: #000000;
# }
# #T_84246_row5_col3 {
#   background-color: #f7814c;
#   color: #f1f1f1;
# }
# #T_84246_row6_col1 {
#   background-color: #08773f;
#   color: #f1f1f1;
# }
# #T_84246_row6_col3 {
#   background-color: #fed481;
#   color: #000000;
# }
# #T_84246_row7_col2 {
#   background-color: #9bd469;
#   color: #000000;
# }
# #T_84246_row7_col3 {
#   background-color: #fdb96a;
#   color: #000000;
# }
# #T_84246_row8_col1 {
#   background-color: #c82227;
#   color: #f1f1f1;
# }
# #T_84246_row9_col1 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# #T_84246_row9_col3 {
#   background-color: #f57547;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_84246">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_84246_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_84246_level0_col1" class="col_heading level0 col1" >Precision</th>
#       <th id="T_84246_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_84246_level0_col3" class="col_heading level0 col3" >F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_84246_level0_row0" class="row_heading level0 row0" >dirty_DBLP-ACM</th>
#       <td id="T_84246_row0_col0" class="data row0 col0" >0.928730</td>
#       <td id="T_84246_row0_col1" class="data row0 col1" >0.736215</td>
#       <td id="T_84246_row0_col2" class="data row0 col2" >0.939752</td>
#       <td id="T_84246_row0_col3" class="data row0 col3" >0.825625</td>
#     </tr>
#     <tr>
#       <th id="T_84246_level0_row1" class="row_heading level0 row1" >dirty_iTunes-Amazon</th>
#       <td id="T_84246_row1_col0" class="data row1 col0" >0.717890</td>
#       <td id="T_84246_row1_col1" class="data row1 col1" >0.462687</td>
#       <td id="T_84246_row1_col2" class="data row1 col2" >0.861111</td>
#       <td id="T_84246_row1_col3" class="data row1 col3" >0.601942</td>
#     </tr>
#     <tr>
#       <th id="T_84246_level0_row2" class="row_heading level0 row2" >dirty_Walmart-Amazon</th>
#       <td id="T_84246_row2_col0" class="data row2 col0" >0.926672</td>
#       <td id="T_84246_row2_col1" class="data row2 col1" >0.612648</td>
#       <td id="T_84246_row2_col2" class="data row2 col2" >0.602332</td>
#       <td id="T_84246_row2_col3" class="data row2 col3" >0.607446</td>
#     </tr>
#     <tr>
#       <th id="T_84246_level0_row3" class="row_heading level0 row3" >structured_DBLP-ACM</th>
#       <td id="T_84246_row3_col0" class="data row3 col0" >0.905884</td>
#       <td id="T_84246_row3_col1" class="data row3 col1" >0.658656</td>
#       <td id="T_84246_row3_col2" class="data row3 col2" >0.987613</td>
#       <td id="T_84246_row3_col3" class="data row3 col3" >0.790268</td>
#     </tr>
#     <tr>
#       <th id="T_84246_level0_row4" class="row_heading level0 row4" >structured_iTunes-Amazon</th>
#       <td id="T_84246_row4_col0" class="data row4 col0" >0.642202</td>
#       <td id="T_84246_row4_col1" class="data row4 col1" >0.398305</td>
#       <td id="T_84246_row4_col2" class="data row4 col2" >0.870370</td>
#       <td id="T_84246_row4_col3" class="data row4 col3" >0.546512</td>
#     </tr>
#     <tr>
#       <th id="T_84246_level0_row5" class="row_heading level0 row5" >structured_Walmart-Amazon</th>
#       <td id="T_84246_row5_col0" class="data row5 col0" >0.944241</td>
#       <td id="T_84246_row5_col1" class="data row5 col1" >0.775832</td>
#       <td id="T_84246_row5_col2" class="data row5 col2" >0.573834</td>
#       <td id="T_84246_row5_col3" class="data row5 col3" >0.659717</td>
#     </tr>
#     <tr>
#       <th id="T_84246_level0_row6" class="row_heading level0 row6" >structured_Beer</th>
#       <td id="T_84246_row6_col0" class="data row6 col0" >0.928375</td>
#       <td id="T_84246_row6_col1" class="data row6 col1" >0.916667</td>
#       <td id="T_84246_row6_col2" class="data row6 col2" >0.589286</td>
#       <td id="T_84246_row6_col3" class="data row6 col3" >0.717391</td>
#     </tr>
#     <tr>
#       <th id="T_84246_level0_row7" class="row_heading level0 row7" >structured_Fodors-Zagats</th>
#       <td id="T_84246_row7_col0" class="data row7 col0" >0.948413</td>
#       <td id="T_84246_row7_col1" class="data row7 col1" >0.728972</td>
#       <td id="T_84246_row7_col2" class="data row7 col2" >0.886364</td>
#       <td id="T_84246_row7_col3" class="data row7 col3" >0.800000</td>
#     </tr>
#     <tr>
#       <th id="T_84246_level0_row8" class="row_heading level0 row8" >structured_Amazon-Google</th>
#       <td id="T_84246_row8_col0" class="data row8 col0" >0.894352</td>
#       <td id="T_84246_row8_col1" class="data row8 col1" >0.481100</td>
#       <td id="T_84246_row8_col2" class="data row8 col2" >0.448718</td>
#       <td id="T_84246_row8_col3" class="data row8 col3" >0.464345</td>
#     </tr>
#     <tr>
#       <th id="T_84246_level0_row9" class="row_heading level0 row9" >textual_Abt-Buy</th>
#       <td id="T_84246_row9_col0" class="data row9 col0" >0.938592</td>
#       <td id="T_84246_row9_col1" class="data row9 col1" >0.768645</td>
#       <td id="T_84246_row9_col2" class="data row9 col2" >0.612864</td>
#       <td id="T_84246_row9_col3" class="data row9 col3" >0.681972</td>
#     </tr>
#   </tbody>
# </table>

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

def calculate_metrics(df):
    df = df[df['pred'] != -1]
    metrics = {}
    for name, group in df.groupby(['general_or_domain', 'simple_or_complex']):
        label = group['label']
        pred = group['pred']
        metrics[name] = {
            'Accuracy': accuracy_score(label, pred),
            'Precision': precision_score(label, pred, zero_division=0),
            'Recall': recall_score(label, pred, zero_division=0),
            'F1': f1_score(label, pred, zero_division=0)
        }
    return metrics

results = {}
for name, df in datasets.items():
    results.update({(name,) + key: value for key, value in calculate_metrics(df).items()})

# Now sorted_results is a new dictionary with keys in alphabetical order

df_all = pd.DataFrame(results).T
df_all.index.names = ['Dataset', 'GeneralOrDomain', 'SimpleOrComplex']
df_all.style.background_gradient(subset=['Accuracy', 'Precision', 'Recall', 'F1'], cmap='RdYlGn')
# Out:
# <style type="text/css">
# #T_4f1e6_row0_col0, #T_4f1e6_row0_col3, #T_4f1e6_row24_col0, #T_4f1e6_row26_col0, #T_4f1e6_row37_col1 {
#   background-color: #0e8245;
#   color: #f1f1f1;
# }
# #T_4f1e6_row0_col1 {
#   background-color: #b1de71;
#   color: #000000;
# }
# #T_4f1e6_row0_col2 {
#   background-color: #016a38;
#   color: #f1f1f1;
# }
# #T_4f1e6_row1_col0, #T_4f1e6_row5_col1, #T_4f1e6_row36_col2 {
#   background-color: #108647;
#   color: #f1f1f1;
# }
# #T_4f1e6_row1_col1, #T_4f1e6_row17_col1 {
#   background-color: #87cb67;
#   color: #000000;
# }
# #T_4f1e6_row1_col2, #T_4f1e6_row15_col0, #T_4f1e6_row17_col0 {
#   background-color: #4bb05c;
#   color: #f1f1f1;
# }
# #T_4f1e6_row1_col3, #T_4f1e6_row3_col2, #T_4f1e6_row9_col1, #T_4f1e6_row31_col2 {
#   background-color: #199750;
#   color: #f1f1f1;
# }
# #T_4f1e6_row2_col0, #T_4f1e6_row13_col3 {
#   background-color: #279f53;
#   color: #f1f1f1;
# }
# #T_4f1e6_row2_col1 {
#   background-color: #f5fbb2;
#   color: #000000;
# }
# #T_4f1e6_row2_col2, #T_4f1e6_row4_col2, #T_4f1e6_row12_col2, #T_4f1e6_row14_col2, #T_4f1e6_row25_col1, #T_4f1e6_row29_col1, #T_4f1e6_row30_col2, #T_4f1e6_row31_col0, #T_4f1e6_row31_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_4f1e6_row2_col3, #T_4f1e6_row22_col2 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
# }
# #T_4f1e6_row3_col0, #T_4f1e6_row13_col0, #T_4f1e6_row36_col3 {
#   background-color: #18954f;
#   color: #f1f1f1;
# }
# #T_4f1e6_row3_col1 {
#   background-color: #d1ec86;
#   color: #000000;
# }
# #T_4f1e6_row3_col3 {
#   background-color: #36a657;
#   color: #f1f1f1;
# }
# #T_4f1e6_row4_col0, #T_4f1e6_row39_col3 {
#   background-color: #fee593;
#   color: #000000;
# }
# #T_4f1e6_row4_col1 {
#   background-color: #ea5739;
#   color: #f1f1f1;
# }
# #T_4f1e6_row4_col3, #T_4f1e6_row34_col3 {
#   background-color: #eef8a8;
#   color: #000000;
# }
# #T_4f1e6_row5_col0, #T_4f1e6_row21_col0 {
#   background-color: #16914d;
#   color: #f1f1f1;
# }
# #T_4f1e6_row5_col2, #T_4f1e6_row7_col2 {
#   background-color: #9dd569;
#   color: #000000;
# }
# #T_4f1e6_row5_col3, #T_4f1e6_row10_col0, #T_4f1e6_row12_col0 {
#   background-color: #1b9950;
#   color: #f1f1f1;
# }
# #T_4f1e6_row6_col0 {
#   background-color: #d93429;
#   color: #f1f1f1;
# }
# #T_4f1e6_row6_col1 {
#   background-color: #b50f26;
#   color: #f1f1f1;
# }
# #T_4f1e6_row6_col2, #T_4f1e6_row16_col2, #T_4f1e6_row18_col2, #T_4f1e6_row22_col0, #T_4f1e6_row38_col0 {
#   background-color: #0a7b41;
#   color: #f1f1f1;
# }
# #T_4f1e6_row6_col3 {
#   background-color: #fedc88;
#   color: #000000;
# }
# #T_4f1e6_row7_col0 {
#   background-color: #63bc62;
#   color: #f1f1f1;
# }
# #T_4f1e6_row7_col1 {
#   background-color: #d7ee8a;
#   color: #000000;
# }
# #T_4f1e6_row7_col3 {
#   background-color: #84ca66;
#   color: #000000;
# }
# #T_4f1e6_row8_col0 {
#   background-color: #128a49;
#   color: #f1f1f1;
# }
# #T_4f1e6_row8_col1 {
#   background-color: #fff1a8;
#   color: #000000;
# }
# #T_4f1e6_row8_col2, #T_4f1e6_row9_col0, #T_4f1e6_row39_col0 {
#   background-color: #17934e;
#   color: #f1f1f1;
# }
# #T_4f1e6_row8_col3 {
#   background-color: #7fc866;
#   color: #000000;
# }
# #T_4f1e6_row9_col2 {
#   background-color: #da362a;
#   color: #f1f1f1;
# }
# #T_4f1e6_row9_col3 {
#   background-color: #f57547;
#   color: #f1f1f1;
# }
# #T_4f1e6_row10_col1 {
#   background-color: #fdc776;
#   color: #000000;
# }
# #T_4f1e6_row10_col2, #T_4f1e6_row23_col0 {
#   background-color: #138c4a;
#   color: #f1f1f1;
# }
# #T_4f1e6_row10_col3, #T_4f1e6_row20_col1, #T_4f1e6_row32_col2 {
#   background-color: #addc6f;
#   color: #000000;
# }
# #T_4f1e6_row11_col0 {
#   background-color: #15904c;
#   color: #f1f1f1;
# }
# #T_4f1e6_row11_col1 {
#   background-color: #b3df72;
#   color: #000000;
# }
# #T_4f1e6_row11_col2, #T_4f1e6_row21_col3, #T_4f1e6_row23_col2 {
#   background-color: #fba35c;
#   color: #000000;
# }
# #T_4f1e6_row11_col3 {
#   background-color: #fee797;
#   color: #000000;
# }
# #T_4f1e6_row12_col1 {
#   background-color: #e6f59d;
#   color: #000000;
# }
# #T_4f1e6_row12_col3, #T_4f1e6_row14_col0, #T_4f1e6_row33_col0 {
#   background-color: #30a356;
#   color: #f1f1f1;
# }
# #T_4f1e6_row13_col1, #T_4f1e6_row32_col3 {
#   background-color: #dcf08f;
#   color: #000000;
# }
# #T_4f1e6_row13_col2, #T_4f1e6_row29_col0 {
#   background-color: #06733d;
#   color: #f1f1f1;
# }
# #T_4f1e6_row14_col1 {
#   background-color: #fdfebc;
#   color: #000000;
# }
# #T_4f1e6_row14_col3 {
#   background-color: #4eb15d;
#   color: #f1f1f1;
# }
# #T_4f1e6_row15_col1 {
#   background-color: #feefa3;
#   color: #000000;
# }
# #T_4f1e6_row15_col2, #T_4f1e6_row20_col0, #T_4f1e6_row21_col1, #T_4f1e6_row36_col0 {
#   background-color: #07753e;
#   color: #f1f1f1;
# }
# #T_4f1e6_row15_col3 {
#   background-color: #75c465;
#   color: #000000;
# }
# #T_4f1e6_row16_col0 {
#   background-color: #fee08b;
#   color: #000000;
# }
# #T_4f1e6_row16_col1 {
#   background-color: #e65036;
#   color: #f1f1f1;
# }
# #T_4f1e6_row16_col3 {
#   background-color: #f7fcb4;
#   color: #000000;
# }
# #T_4f1e6_row17_col2, #T_4f1e6_row27_col3 {
#   background-color: #cbe982;
#   color: #000000;
# }
# #T_4f1e6_row17_col3 {
#   background-color: #7dc765;
#   color: #000000;
# }
# #T_4f1e6_row18_col0, #T_4f1e6_row18_col1, #T_4f1e6_row33_col2, #T_4f1e6_row33_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_4f1e6_row18_col3 {
#   background-color: #feca79;
#   color: #000000;
# }
# #T_4f1e6_row19_col0 {
#   background-color: #fffdbc;
#   color: #000000;
# }
# #T_4f1e6_row19_col1 {
#   background-color: #f47044;
#   color: #f1f1f1;
# }
# #T_4f1e6_row19_col2, #T_4f1e6_row32_col0 {
#   background-color: #2aa054;
#   color: #f1f1f1;
# }
# #T_4f1e6_row19_col3 {
#   background-color: #ecf7a6;
#   color: #000000;
# }
# #T_4f1e6_row20_col2, #T_4f1e6_row22_col3, #T_4f1e6_row34_col0 {
#   background-color: #54b45f;
#   color: #f1f1f1;
# }
# #T_4f1e6_row20_col3, #T_4f1e6_row35_col0 {
#   background-color: #39a758;
#   color: #f1f1f1;
# }
# #T_4f1e6_row21_col2 {
#   background-color: #e54e35;
#   color: #f1f1f1;
# }
# #T_4f1e6_row22_col1, #T_4f1e6_row38_col1 {
#   background-color: #d9ef8b;
#   color: #000000;
# }
# #T_4f1e6_row23_col1 {
#   background-color: #73c264;
#   color: #000000;
# }
# #T_4f1e6_row23_col3, #T_4f1e6_row27_col2 {
#   background-color: #feeda1;
#   color: #000000;
# }
# #T_4f1e6_row24_col1, #T_4f1e6_row26_col1, #T_4f1e6_row31_col1, #T_4f1e6_row38_col3 {
#   background-color: #2da155;
#   color: #f1f1f1;
# }
# #T_4f1e6_row24_col2, #T_4f1e6_row26_col2 {
#   background-color: #afdd70;
#   color: #000000;
# }
# #T_4f1e6_row24_col3, #T_4f1e6_row26_col3 {
#   background-color: #3faa59;
#   color: #f1f1f1;
# }
# #T_4f1e6_row25_col0 {
#   background-color: #219c52;
#   color: #f1f1f1;
# }
# #T_4f1e6_row25_col2 {
#   background-color: #fecc7b;
#   color: #000000;
# }
# #T_4f1e6_row25_col3 {
#   background-color: #e2f397;
#   color: #000000;
# }
# #T_4f1e6_row27_col0 {
#   background-color: #249d53;
#   color: #f1f1f1;
# }
# #T_4f1e6_row27_col1 {
#   background-color: #51b35e;
#   color: #f1f1f1;
# }
# #T_4f1e6_row28_col0 {
#   background-color: #04703b;
#   color: #f1f1f1;
# }
# #T_4f1e6_row28_col1 {
#   background-color: #91d068;
#   color: #000000;
# }
# #T_4f1e6_row28_col2, #T_4f1e6_row38_col2 {
#   background-color: #0c7f43;
#   color: #f1f1f1;
# }
# #T_4f1e6_row28_col3 {
#   background-color: #0b7d42;
#   color: #f1f1f1;
# }
# #T_4f1e6_row29_col2 {
#   background-color: #c1e57b;
#   color: #000000;
# }
# #T_4f1e6_row29_col3 {
#   background-color: #33a456;
#   color: #f1f1f1;
# }
# #T_4f1e6_row30_col0, #T_4f1e6_row39_col1 {
#   background-color: #48ae5c;
#   color: #f1f1f1;
# }
# #T_4f1e6_row30_col1 {
#   background-color: #fdaf62;
#   color: #000000;
# }
# #T_4f1e6_row30_col3 {
#   background-color: #b5df74;
#   color: #000000;
# }
# #T_4f1e6_row32_col1 {
#   background-color: #fdc574;
#   color: #000000;
# }
# #T_4f1e6_row33_col1 {
#   background-color: #fffbb8;
#   color: #000000;
# }
# #T_4f1e6_row34_col1 {
#   background-color: #f57748;
#   color: #f1f1f1;
# }
# #T_4f1e6_row34_col2 {
#   background-color: #57b65f;
#   color: #f1f1f1;
# }
# #T_4f1e6_row35_col1 {
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_4f1e6_row35_col2 {
#   background-color: #b71126;
#   color: #f1f1f1;
# }
# #T_4f1e6_row35_col3 {
#   background-color: #bb1526;
#   color: #f1f1f1;
# }
# #T_4f1e6_row36_col1 {
#   background-color: #b9e176;
#   color: #000000;
# }
# #T_4f1e6_row37_col0 {
#   background-color: #1e9a51;
#   color: #f1f1f1;
# }
# #T_4f1e6_row37_col2 {
#   background-color: #e14430;
#   color: #f1f1f1;
# }
# #T_4f1e6_row37_col3, #T_4f1e6_row39_col2 {
#   bac

# %%
def calculate_metrics(df):
    df = df[df['pred'] != -1]
    metrics = {}
    for category in ['general_or_domain', 'simple_or_complex']:
        for name, group in df.groupby(category):
            metrics[name] = {
                'F1': f1_score(group['label'], group['pred'])
            }
    return metrics

results = []
for name, df in datasets.items():
    metrics = calculate_metrics(df)
    results.append((name, 
                    metrics.get('domain', {}).get('F1', None), 
                    metrics.get('general', {}).get('F1', None),
                    metrics.get('simple', {}).get('F1', None),
                    metrics.get('complex', {}).get('F1', None)))

df_all = pd.DataFrame(results, columns=['Dataset', 'Domain F1', 'General F1', 'Simple F1', 'Complex F1'])
df_all.set_index('Dataset', inplace=True)
df_all.style.background_gradient(subset=['Domain F1', 'General F1', 'Simple F1', 'Complex F1'], cmap='RdYlGn', axis=1)
# Out:
# <style type="text/css">
# #T_d0412_row0_col0, #T_d0412_row1_col2, #T_d0412_row2_col3, #T_d0412_row3_col0, #T_d0412_row4_col2, #T_d0412_row5_col3, #T_d0412_row6_col3, #T_d0412_row7_col2, #T_d0412_row8_col3, #T_d0412_row9_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_d0412_row0_col1, #T_d0412_row1_col3, #T_d0412_row2_col2, #T_d0412_row3_col1, #T_d0412_row4_col3, #T_d0412_row5_col2, #T_d0412_row6_col2, #T_d0412_row7_col3, #T_d0412_row8_col2, #T_d0412_row9_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_d0412_row0_col2 {
#   background-color: #fed27f;
#   color: #000000;
# }
# #T_d0412_row0_col3 {
#   background-color: #e5f49b;
#   color: #000000;
# }
# #T_d0412_row1_col0 {
#   background-color: #e8f59f;
#   color: #000000;
# }
# #T_d0412_row1_col1 {
#   background-color: #e24731;
#   color: #f1f1f1;
# }
# #T_d0412_row2_col0 {
#   background-color: #c3e67d;
#   color: #000000;
# }
# #T_d0412_row2_col1 {
#   background-color: #b1de71;
#   color: #000000;
# }
# #T_d0412_row3_col2 {
#   background-color: #fdb567;
#   color: #000000;
# }
# #T_d0412_row3_col3 {
#   background-color: #bde379;
#   color: #000000;
# }
# #T_d0412_row4_col0 {
#   background-color: #249d53;
#   color: #f1f1f1;
# }
# #T_d0412_row4_col1 {
#   background-color: #b30d26;
#   color: #f1f1f1;
# }
# #T_d0412_row5_col0 {
#   background-color: #dff293;
#   color: #000000;
# }
# #T_d0412_row5_col1 {
#   background-color: #c1e57b;
#   color: #000000;
# }
# #T_d0412_row6_col0 {
#   background-color: #fbfdba;
#   color: #000000;
# }
# #T_d0412_row6_col1 {
#   background-color: #e2f397;
#   color: #000000;
# }
# #T_d0412_row7_col0 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
# }
# #T_d0412_row7_col1 {
#   background-color: #ce2827;
#   color: #f1f1f1;
# }
# #T_d0412_row8_col0 {
#   background-color: #abdb6d;
#   color: #000000;
# }
# #T_d0412_row8_col1 {
#   background-color: #b3df72;
#   color: #000000;
# }
# #T_d0412_row9_col0 {
#   background-color: #d5ed88;
#   color: #000000;
# }
# #T_d0412_row9_col1 {
#   background-color: #b7e075;
#   color: #000000;
# }
# </style>
# <table id="T_d0412">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d0412_level0_col0" class="col_heading level0 col0" >Domain F1</th>
#       <th id="T_d0412_level0_col1" class="col_heading level0 col1" >General F1</th>
#       <th id="T_d0412_level0_col2" class="col_heading level0 col2" >Simple F1</th>
#       <th id="T_d0412_level0_col3" class="col_heading level0 col3" >Complex F1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Dataset</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d0412_level0_row0" class="row_heading level0 row0" >dirty_DBLP_ACM</th>
#       <td id="T_d0412_row0_col0" class="data row0 col0" >0.852834</td>
#       <td id="T_d0412_row0_col1" class="data row0 col1" >0.800943</td>
#       <td id="T_d0412_row0_col2" class="data row0 col2" >0.820325</td>
#       <td id="T_d0412_row0_col3" class="data row0 col3" >0.830366</td>
#     </tr>
#     <tr>
#       <th id="T_d0412_level0_row1" class="row_heading level0 row1" >dirty_iTunes_Amazon</th>
#       <td id="T_d0412_row1_col0" class="data row1 col0" >0.661972</td>
#       <td id="T_d0412_row1_col1" class="data row1 col1" >0.550898</td>
#       <td id="T_d0412_row1_col2" class="data row1 col2" >0.776699</td>
#       <td id="T_d0412_row1_col3" class="data row1 col3" >0.514563</td>
#     </tr>
#     <tr>
#       <th id="T_d0412_level0_row2" class="row_heading level0 row2" >dirty_Walmart_Amazon</th>
#       <td id="T_d0412_row2_col0" class="data row2 col0" >0.601671</td>
#       <td id="T_d0412_row2_col1" class="data row2 col1" >0.612546</td>
#       <td id="T_d0412_row2_col2" class="data row2 col2" >0.416988</td>
#       <td id="T_d0412_row2_col3" class="data row2 col3" >0.704837</td>
#     </tr>
#     <tr>
#       <th id="T_d0412_level0_row3" class="row_heading level0 row3" >structured_DBLP_ACM</th>
#       <td id="T_d0412_row3_col0" class="data row3 col0" >0.816954</td>
#       <td id="T_d0412_row3_col1" class="data row3 col1" >0.765271</td>
#       <td id="T_d0412_row3_col2" class="data row3 col2" >0.781433</td>
#       <td id="T_d0412_row3_col3" class="data row3 col3" >0.799099</td>
#     </tr>
#     <tr>
#       <th id="T_d0412_level0_row4" class="row_heading level0 row4" >structured_iTunes_Amazon</th>
#       <td id="T_d0412_row4_col0" class="data row4 col0" >0.619718</td>
#       <td id="T_d0412_row4_col1" class="data row4 col1" >0.495050</td>
#       <td id="T_d0412_row4_col2" class="data row4 col2" >0.636364</td>
#       <td id="T_d0412_row4_col3" class="data row4 col3" >0.490566</td>
#     </tr>
#     <tr>
#       <th id="T_d0412_level0_row5" class="row_heading level0 row5" >structured_Walmart_Amazon</th>
#       <td id="T_d0412_row5_col0" class="data row5 col0" >0.647975</td>
#       <td id="T_d0412_row5_col1" class="data row5 col1" >0.670471</td>
#       <td id="T_d0412_row5_col2" class="data row5 col2" >0.446602</td>
#       <td id="T_d0412_row5_col3" class="data row5 col3" >0.792271</td>
#     </tr>
#     <tr>
#       <th id="T_d0412_level0_row6" class="row_heading level0 row6" >structured_Beer</th>
#       <td id="T_d0412_row6_col0" class="data row6 col0" >0.711111</td>
#       <td id="T_d0412_row6_col1" class="data row6 col1" >0.723404</td>
#       <td id="T_d0412_row6_col2" class="data row6 col2" >0.619048</td>
#       <td id="T_d0412_row6_col3" class="data row6 col3" >0.800000</td>
#     </tr>
#     <tr>
#       <th id="T_d0412_level0_row7" class="row_heading level0 row7" >structured_Fodors_Zagats</th>
#       <td id="T_d0412_row7_col0" class="data row7 col0" >0.847059</td>
#       <td id="T_d0412_row7_col1" class="data row7 col1" >0.763636</td>
#       <td id="T_d0412_row7_col2" class="data row7 col2" >0.864198</td>
#       <td id="T_d0412_row7_col3" class="data row7 col3" >0.754386</td>
#     </tr>
#     <tr>
#       <th id="T_d0412_level0_row8" class="row_heading level0 row8" >structured_Amazon_Google</th>
#       <td id="T_d0412_row8_col0" class="data row8 col0" >0.467153</td>
#       <td id="T_d0412_row8_col1" class="data row8 col1" >0.462006</td>
#       <td id="T_d0412_row8_col2" class="data row8 col2" >0.193772</td>
#       <td id="T_d0412_row8_col3" class="data row8 col3" >0.591389</td>
#     </tr>
#     <tr>
#       <th id="T_d0412_level0_row9" class="row_heading level0 row9" >textual_Abt_Buy</th>
#       <td id="T_d0412_row9_col0" class="data row9 col0" >0.670391</td>
#       <td id="T_d0412_row9_col1" class="data row9 col1" >0.692810</td>
#       <td id="T_d0412_row9_col2" class="data row9 col2" >0.424581</td>
#       <td id="T_d0412_row9_col3" class="data row9 col3" >0.828390</td>
#     </tr>
#   </tbody>
# </table>

# %%
def calculate_metrics(df):
    df = df[df['pred'] != -1]
    metrics = {}
    for (general_or_domain, simple_or_complex), group in df.groupby(['general_or_domain', 'simple_or_complex']):
        name = f'{general_or_domain}_{simple_or_complex}'
        metrics[name] = {
            'F1': f1_score(group['label'], group['pred'])
        }
    return metrics

results = []
for name, df in datasets.items():
    metrics = calculate_metrics(df)
    results.append((name, 
                    metrics.get('domain_simple', {}).get('F1', None), 
                    metrics.get('domain_complex', {}).get('F1', None),
                    metrics.get('general_simple', {}).get('F1', None),
                    metrics.get('general_complex', {}).get('F1', None)))

df_all = pd.DataFrame(results, columns=['Dataset', 'Domain Simple F1', 'Domain Complex F1', 'General Simple F1', 'General Complex F1'])
df_all['Mean F1'] = df_all[['Domain Simple F1', 'Domain Complex F1', 'General Simple F1', 'General Complex F1']].mean(axis=1)
df_all.set_index('Dataset', inplace=True)
df_all.style.background_gradient(subset=['Domain Simple F1', 'Domain Complex F1', 'General Simple F1', 'General Complex F1', 'Mean F1'], cmap='RdYlGn', axis=1)
# Out:
# <style type="text/css">
# #T_8c37f_row0_col0, #T_8c37f_row6_col4 {
#   background-color: #eef8a8;
#   color: #000000;
# }
# #T_8c37f_row0_col1, #T_8c37f_row1_col0, #T_8c37f_row2_col1, #T_8c37f_row3_col0, #T_8c37f_row4_col0, #T_8c37f_row5_col1, #T_8c37f_row6_col1, #T_8c37f_row6_col3, #T_8c37f_row7_col2, #T_8c37f_row8_col1, #T_8c37f_row9_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_8c37f_row0_col2 {
#   background-color: #e65036;
#   color: #f1f1f1;
# }
# #T_8c37f_row0_col3, #T_8c37f_row1_col3, #T_8c37f_row2_col0, #T_8c37f_row3_col2, #T_8c37f_row4_col3, #T_8c37f_row5_col0, #T_8c37f_row6_col0, #T_8c37f_row7_col3, #T_8c37f_row8_col0, #T_8c37f_row9_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_8c37f_row0_col4 {
#   background-color: #fee797;
#   color: #000000;
# }
# #T_8c37f_row1_col1 {
#   background-color: #fdad60;
#   color: #000000;
# }
# #T_8c37f_row1_col2 {
#   background-color: #9dd569;
#   color: #000000;
# }
# #T_8c37f_row1_col4 {
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_8c37f_row2_col2 {
#   background-color: #feda86;
#   color: #000000;
# }
# #T_8c37f_row2_col3 {
#   background-color: #33a456;
#   color: #f1f1f1;
# }
# #T_8c37f_row2_col4 {
#   background-color: #e6f59d;
#   color: #000000;
# }
# #T_8c37f_row3_col1 {
#   background-color: #17934e;
#   color: #f1f1f1;
# }
# #T_8c37f_row3_col3 {
#   background-color: #f5fbb2;
#   color: #000000;
# }
# #T_8c37f_row3_col4 {
#   background-color: #d5ed88;
#   color: #000000;
# }
# #T_8c37f_row4_col1 {
#   background-color: #fee491;
#   color: #000000;
# }
# #T_8c37f_row4_col2 {
#   background-color: #fff7b2;
#   color: #000000;
# }
# #T_8c37f_row4_col4 {
#   background-color: #fff6b0;
#   color: #000000;
# }
# #T_8c37f_row5_col2 {
#   background-color: #fba05b;
#   color: #000000;
# }
# #T_8c37f_row5_col3 {
#   background-color: #108647;
#   color: #f1f1f1;
# }
# #T_8c37f_row5_col4 {
#   background-color: #ebf7a3;
#   color: #000000;
# }
# #T_8c37f_row6_col2 {
#   background-color: #ee613e;
#   color: #f1f1f1;
# }
# #T_8c37f_row7_col0 {
#   background-color: #daf08d;
#   color: #000000;
# }
# #T_8c37f_row7_col1 {
#   background-color: #36a657;
#   color: #f1f1f1;
# }
# #T_8c37f_row7_col4 {
#   background-color: #d1ec86;
#   color: #000000;
# }
# #T_8c37f_row8_col2 {
#   background-color: #ca2427;
#   color: #f1f1f1;
# }
# #T_8c37f_row8_col3 {
#   background-color: #148e4b;
#   color: #f1f1f1;
# }
# #T_8c37f_row8_col4 {
#   background-color: #fffebe;
#   color: #000000;
# }
# #T_8c37f_row9_col2 {
#   background-color: #f88c51;
#   color: #f1f1f1;
# }
# #T_8c37f_row9_col3 {
#   background-color: #0c7f43;
#   color: #f1f1f1;
# }
# #T_8c37f_row9_col4 {
#   background-color: #ecf7a6;
#   color: #000000;
# }
# </style>
# <table id="T_8c37f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8c37f_level0_col0" class="col_heading level0 col0" >Domain Simple F1</th>
#       <th id="T_8c37f_level0_col1" class="col_heading level0 col1" >Domain Complex F1</th>
#       <th id="T_8c37f_level0_col2" class="col_heading level0 col2" >General Simple F1</th>
#       <th id="T_8c37f_level0_col3" class="col_heading level0 col3" >General Complex F1</th>
#       <th id="T_8c37f_level0_col4" class="col_heading level0 col4" >Mean F1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Dataset</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8c37f_level0_row0" class="row_heading level0 row0" >dirty_DBLP_ACM</th>
#       <td id="T_8c37f_row0_col0" class="data row0 col0" >0.835359</td>
#       <td id="T_8c37f_row0_col1" class="data row0 col1" >0.868369</td>
#       <td id="T_8c37f_row0_col2" class="data row0 col2" >0.806773</td>
#       <td id="T_8c37f_row0_col3" class="data row0 col3" >0.795699</td>
#       <td id="T_8c37f_row0_col4" class="data row0 col4" >0.826550</td>
#     </tr>
#     <tr>
#       <th id="T_8c37f_level0_row1" class="row_heading level0 row1" >dirty_iTunes_Amazon</th>
#       <td id="T_8c37f_row1_col0" class="data row1 col0" >0.833333</td>
#       <td id="T_8c37f_row1_col1" class="data row1 col1" >0.574468</td>
#       <td id="T_8c37f_row1_col2" class="data row1 col2" >0.727273</td>
#       <td id="T_8c37f_row1_col3" class="data row1 col3" >0.464286</td>
#       <td id="T_8c37f_row1_col4" class="data row1 col4" >0.649840</td>
#     </tr>
#     <tr>
#       <th id="T_8c37f_level0_row2" class="row_heading level0 row2" >dirty_Walmart_Amazon</th>
#       <td id="T_8c37f_row2_col0" class="data row2 col0" >0.331915</td>
#       <td id="T_8c37f_row2_col1" class="data row2 col1" >0.732919</td>
#       <td id="T_8c37f_row2_col2" class="data row2 col2" >0.487633</td>
#       <td id="T_8c37f_row2_col3" class="data row2 col3" >0.679245</td>
#       <td id="T_8c37f_row2_col4" class="data row2 col4" >0.557928</td>
#     </tr>
#     <tr>
#       <th id="T_8c37f_level0_row3" class="row_heading level0 row3" >structured_DBLP_ACM</th>
#       <td id="T_8c37f_row3_col0" class="data row3 col0" >0.820416</td>
#       <td id="T_8c37f_row3_col1" class="data row3 col1" >0.813590</td>
#       <td id="T_8c37f_row3_col2" class="data row3 col2" >0.745909</td>
#       <td id="T_8c37f_row3_col3" class="data row3 col3" >0.785146</td>
#       <td id="T_8c37f_row3_col4" class="data row3 col4" >0.791265</td>
#     </tr>
#     <tr>
#       <th id="T_8c37f_level0_row4" class="row_heading level0 row4" >structured_iTunes_Amazon</th>
#       <td id="T_8c37f_row4_col0" class="data row4 col0" >0.734694</td>
#       <td id="T_8c37f_row4_col1" class="data row4 col1" >0.559140</td>
#       <td id="T_8c37f_row4_col2" class="data row4 col2" >0.578313</td>
#       <td id="T_8c37f_row4_col3" class="data row4 col3" >0.436975</td>
#       <td id="T_8c37f_row4_col4" class="data row4 col4" >0.577280</td>
#     </tr>
#     <tr>
#       <th id="T_8c37f_level0_row5" class="row_heading level0 row5" >structured_Walmart_Amazon</th>
#       <td id="T_8c37f_row5_col0" class="data row5 col0" >0.383333</td>
#       <td id="T_8c37f_row5_col1" class="data row5 col1" >0.805970</td>
#       <td id="T_8c37f_row5_col2" class="data row5 col2" >0.501818</td>
#       <td id="T_8c37f_row5_col3" class="data row5 col3" >0.779343</td>
#       <td id="T_8c37f_row5_col4" class="data row5 col4" >0.617616</td>
#     </tr>
#     <tr>
#       <th id="T_8c37f_level0_row6" class="row_heading level0 row6" >structured_Beer</th>
#       <td id="T_8c37f_row6_col0" class="data row6 col0" >0.600000</td>
#       <td id="T_8c37f_row6_col1" class="data row6 col1" >0.800000</td>
#       <td id="T_8c37f_row6_col2" class="data row6 col2" >0.636364</td>
#       <td id="T_8c37f_row6_col3" class="data row6 col3" >0.800000</td>
#       <td id="T_8c37f_row6_col4" class="data row6 col4" >0.709091</td>
#     </tr>
#     <tr>
#       <th id="T_8c37f_level0_row7" class="row_heading level0 row7" >structured_Fodors_Zagats</th>
#       <td id="T_8c37f_row7_col0" class="data row7 col0" >0.810811</td>
#       <td id="T_8c37f_row7_col1" class="data row7 col1" >0.875000</td>
#       <td id="T_8c37f_row7_col2" class="data row7 col2" >0.909091</td>
#       <td id="T_8c37f_row7_col3" class="data row7 col3" >0.666667</td>
#       <td id="T_8c37f_row7_col4" class="data row7 col4" >0.815392</td>
#     </tr>
#     <tr>
#       <th id="T_8c37f_level0_row8" class="row_heading level0 row8" >structured_Amazon_Google</th>
#       <td id="T_8c37f_row8_col0" class="data row8 col0" >0.176471</td>
#       <td id="T_8c37f_row8_col1" class="data row8 col1" >0.610909</td>
#       <td id="T_8c37f_row8_col2" class="data row8 col2" >0.209150</td>
#       <td id="T_8c37f_row8_col3" class="data row8 col3" >0.575624</td>
#       <td id="T_8c37f_row8_col4" class="data row8 col4" >0.393039</td>
#     </tr>
#     <tr>
#       <th id="T_8c37f_level0_row9" class="row_heading level0 row9" >textual_Abt_Buy</th>
#       <td id="T_8c37f_row9_col0" class="data row9 col0" >0.362205</td>
#       <td id="T_8c37f_row9_col1" class="data row9 col1" >0.839827</td>
#       <td id="T_8c37f_row9_col2" class="data row9 col2" >0.480565</td>
#       <td id="T_8c37f_row9_col3" class="data row9 col3" >0.817427</td>
#       <td id="T_8c37f_row9_col
